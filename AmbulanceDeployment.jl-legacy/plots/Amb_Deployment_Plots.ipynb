# %%
import json
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# In C:\Users\zande\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\zande\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\zande\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In C:\Users\zande\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# ...

# %%
def plot_ambulance_deployment(data, description):
    for model in sorted(data.keys()):
        plt.figure(figsize=(12,5))

        for amb_setting in sorted(data[model].keys()):
            if(int(amb_setting) < 25):
                continue
            station_id = list(range(len(data[model][amb_setting])))
            plt.plot(station_id, data[model][amb_setting], label= str(model + ': ' + amb_setting))

            plt.xticks(np.arange(min(station_id), max(station_id)+1, 1.0))
        plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
        plt.xlabel("Station Id")
        plt.ylabel("# of Ambulances Deployed")
        plt.title(model + " (" + description + ")")
        plt.grid()
        plt.show()

# %% [markdown]
# ## Original Deployment

# %%
with open('inputs/og_deployment.json') as f:
    original_data = json.load(f)

print(original_data.keys())
#print(original_data["Stochastic"])
# Out:
# dict_keys(['MEXCLP', 'Stochastic', 'Robust001', 'Robust005', 'Robust01', 'MALP', 'Robust0001', 'Robust00001'])

# %%
plot_ambulance_deployment(original_data, "Original")

# %% [markdown]
# ## New Deployment after Update

# %%
with open('inputs/amb_deployment.json') as f:
    updated_data = json.load(f)

print(updated_data.keys())
#print(updated_data["Stochastic"])
# Out:
# dict_keys(['Stochastic', 'MEXCLP', 'Robust001', 'Robust005', 'Robust01', 'MALP', 'Robust0001', 'Robust00001'])

# %%
plot_ambulance_deployment(updated_data, "Updated")

# %% [markdown]
# ## Austin Deployment

# %%
with open('inputs/austin_amb_deployment.json') as f:
    austin_data = json.load(f)

print(austin_data.keys())
#print(austin_data["Stochastic"])
# Out:
# dict_keys(['Stochastic', 'MEXCLP', 'MALP'])

# %%
plot_ambulance_deployment(austin_data, "Austin")
